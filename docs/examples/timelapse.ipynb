# %% [markdown]
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/nazifa02/geotask/blob/main/docs/examples/timelapse.ipynb)

# %%
# !pip install geotask
# Out:
# ...
# WARNING: Skipping C:\Users\tasne\miniconda3\envs\geo\Lib\site-packages\vtk-9.2.6.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\tasne\miniconda3\envs\geo\Lib\site-packages\vtk-9.2.6.egg-info due to invalid metadata entry 'name'

# %%
# !pip install netCDF4
# Out:
# ...
# WARNING: Skipping C:\Users\tasne\miniconda3\envs\geo\Lib\site-packages\vtk-9.2.6.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\tasne\miniconda3\envs\geo\Lib\site-packages\vtk-9.2.6.egg-info due to invalid metadata entry 'name'

# %%
import geotask
from geotask.temp import save_yearly_images, show_gif

# %%
netcdf_file = "https://github.com/nazifa02/geotask/blob/main/docs/examples/sacramento_2059.nc"
output_dir = "c:/Users/tasne/Downloads/geotask-1/docs/examples"
output_file = "timelapse_future.gif"
save_yearly_images(netcdf_file, output_dir, output_file)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\xarray\backends\file_manager.py:209, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     208 try:
# --> 209     file = self._cache[self._key]
#     210 except KeyError:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xarray\backends\lru_cache.py:55, in LRUCache.__getitem__(self, key)
#      54 with self._lock:
# ---> 55     value = self._cache[key]
#      56     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('https://github.com/nazifa02/geotask/blob/main/docs/examples/sacramento_2059.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), '14b32d2b-f6bf-4376-8407-a334d2fe6510']
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
show_gif(output_file)
